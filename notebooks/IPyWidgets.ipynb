# %%
import ipywidgets as widgets
from ipywidgets import Image, HTML, HBox, VBox, Box
from ipyevents import Event

# %%
source = open('../data/dario1.jpg', 'rb')
destination = open('../data/dario2.jpg', 'rb')


s = source.read()
d = destination.read()

s_wig = widgets.Image(
    value=s,
    format='jpg',
)


d_wid = widgets.Image(
    value=d,
    format='jpg',
)

# %%
data = []
def on_image_changed(changes):
    print(changes)
    data.append(changes)
    h.value = f"{changes}"

im_events = Event()
im_events.source = s_wig
im_events.watched_events = ['click']
no_drag = Event(source=s_wig, watched_events=['dragstart'], prevent_default_action = True)

h = HTML()
hb = VBox()
hb.children = [s_wig,h]
hb.layout.height = "400"
h.value = "Test"

im_events.on_dom_event(on_image_changed)
hb

# %%
data
# Out:
# []

# %%
image = Image(value=s, format='png')

# The layout bits below make sure the image display looks the same in lab and classic notebook 
image.layout.max_width = '100%'
image.layout.height = 'auto'

im_events = Event()
im_events.source = image
im_events.watched_events = ['click']

no_drag = Event(source=image, watched_events=['dragstart'], prevent_default_action = True)

# %%
vbox = VBox()
vbox.layout.width = "100%"
header = HTML('<h2>Same image, three views</h2>')

images = HBox()
i1 = Box()
i1.layout.height = '100px'
i1.children = [image]

i2 = Box()
i2.children = [image]
i2.layout.width = '100px'

i3 = Box()
i3.layout.border = '5px red solid'
i3.layout.padding = '10px'
i3.layout.width = '300px'
i3.children = [image]

images.children = [i1, i2, i3]

coordinates = HTML('<h3>Click an image to see the click coordinates here</h3>')

vbox.children = [header, images, coordinates]

def update_coords(event):
    coordinates.value = '<h3>Clicked at ({}, {})</h3>'.format(event['dataX'], event['dataY'])
    
im_events.on_dom_event(update_coords)

vbox

# %%
b = Box()
b.children = [
    HTML('<h2>A, three views</h2>'),
    HTML('<h2>Be, three views</h2>'),
]
b
# Out:
# Box(children=(HTML(value='<h2>A, three views</h2>'), HTML(value='<h2>Be, three views</h2>')))

# %%
b
# Out:
# Box(children=(HTML(value='<h2>A, three views</h2>'), HTML(value='<h2>Be, three views</h2>')))

# %%
help(b)
# Out:
# Help on Box in module ipywidgets.widgets.widget_box object:
#
# class Box(ipywidgets.widgets.domwidget.DOMWidget, ipywidgets.widgets.widget_core.CoreWidget)
#  |  Box(*args, **kwargs)
#  |
#  |  Displays multiple widgets in a group.
#  |
#  |  The widgets are laid out horizontally.
#  |
#  |  Parameters
#  |  ----------
#  |  children: iterable of Widget instances
#  |      list of widgets to display
#  |
#  |  box_style: str
#  |      one of 'success', 'info', 'warning' or 'danger', or ''.
#  |      Applies a predefined style to the box. Defaults to '',
#  |      which applies no pre-defined style.
#  |
#  |  Examples
#  |  --------
#  |  >>> import ipywidgets as widgets
#  |  >>> title_widget = widgets.HTML('<em>Box Example</em>')
#  |  >>> slider = widgets.IntSlider()
#  |  >>> widgets.Box([title_widget, slider])
#  |
#  |  Method resolution order:
#  |      Box
#  |      ipywidgets.widgets.domwidget.DOMWidget
#  |      ipywidgets.widgets.widget_core.CoreWidget
# ...
